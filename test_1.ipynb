# %% [markdown]
# <a href="https://colab.research.google.com/github/ROKEYAKHATUN/test-12/blob/main/test_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
variable1 = "Jitu, Sriti connection"
print(variable1)
# Out:
# Jitu, Sriti connection

# %%
test eikhane
